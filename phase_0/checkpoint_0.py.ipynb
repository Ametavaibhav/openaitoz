# %%
import pandas as pd
import laspy

import requests

from dotenv import dotenv_values

# %%
config = dotenv_values()

# %%
## Get a tile from openTopopgraphy

opentop_endpoint = "https://portal.opentopography.org/API/globaldem"

params = {
    "demtype": "AW3D30",
    "south": 24.401,
    "north": 24.444,
    "west": 76.261076,
    "east": 76.294076,
    "API_Key": config['OPENTOPOGRAPHY_KEY']
}

def call_openTopography():
    response = requests.get(opentop_endpoint, params=params)
    return response

# %%
response = call_openTopography()

# %%
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'II*\x00\xc0\x00\x00\x00GDAL_STRUCTURAL_METADATA_SIZE=000140 bytes\nLAYOUT=IFDS_BEFORE_DATA\nBLOCK_ORDER=ROW_MAJOR\nBLOCK_LEADER=SIZE_AS_UINT4\nBLOCK_TRAILER=LAST_4_BYTES_REPEATED\nKNOWN_INCOMPATIBLE_EDITION=NO\n \x00\x12\x00\x00\x01\x03\x00\x01\x00\x00\x00w=\x01\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00B\x01\x03\x00\x01\x00\x00\x00\x00\x01\x00\x00C\x01\x03\x00\x01\x00\x00\x00\x00\x01\x00\x00D\x01\x04\x00\x01\x00\x00\x00B\x02\x00\x00E\x01\x04\x00\x01\x00\x00\x00\x1c/\x00\x00S\x01\x03\x00\x01\x00\x00\x00\x02\x00\x00\x00\x0e\x83\x0c\x00\x03\x00\x00\x00\x9e\x01\x00\x00\x82\x84\x0c\x00\x06\x00\x00\x00\xb6\x01\x00\x00\xaf\x87\x03\x00 \x00\x00\x00\xe6\x01\x00\x00\xb0\x87\x0c\x00\x02\x00\x00\x00&\x02\x00\x00\xb1\x87\x02\x00\x08\x00\x00\x006\x02\x00\x00\x00\x00\x00\x00\xb8\xbf\x9axV42?\xb8\xbf\x9axV42?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xd4!K~\xb1\x10S@0E\x1b\xe8\xb4q8@\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x01\x00\x00\x00\x07\x00\x00\x04\x00\x00\x01\x00\x02\x00\x01\x04\x00\x00\x01\x00\x01\x00\x00\x08\x00\x00\x01\x00\xe6\x10\x01\x08\xb1\x87\x07\x00\x00\x00\x06\x08\x00\x00\x01\x00\x8e#\t\x08\xb0\x87\x01\x00\x01\x00\x0b\x08\xb0\x87\x01\x00\x00\x00\x88mt\x96\x1d\xa4r@\x00\x00\x00@\xa6TXAWGS 84|\x00\x1c/\x00\x00\x80\x11\x80$\x80\t$\x02K\x00\x93@$\xe0\t<\x02Q\x00\x95\x00%P\tX\x02W\x00\x96@%\xa0\tl\x02]\x8f\x80L\x12 \t\x88\x02c\x00\x99@&p\t\xa8\x02l\x00\x9b\x80\'\x00\t\xcek78\x80M\xa0\x13H\x04\xcd\'\x00\x98@%\xe0\tr7\x19\x8a\xc4\xe9%\x88\xec\x92Q*2P(U:\x08\x06\xa3,5\xcb\xc05\x99t\xf6]07\x80g3\x99\xa4\xc2\xba\x014J\xe5\xb30\t\xd4\x02v\x9b\x9c\xacW3\xa0\x04\xee\x01<^\x00\'\x9b\xdd\xeam9\x9b[\xae\x18;}\xea\xf8z\x00\x9f\x00\'\xe0\n\x04\x02\x83\x00\xa1\x00(P\n\x18\x02\x87\x00\xa2\x00(\x9c\xd8\x05\x15\x9e\xcb\xe6t\x08\xb0\n0\x02\x8e\x00\xa4\x00)\x10\x08\x03]\xaf\xd8lv[=\xa6\xd7m\xb7\xdcnw[\xbd\xe6\xf7}\xbf\xe0px\\\x12(\x04\x8f\xc6\x81\x80I@\x12d4\x02R\x00\x94\xe24\xaadj9\x1e\xa3H(\x85\xf9$\x9a\xa3*\xb4\xcb\xa7s+\x1d\xce\xc30\xb4\xd4h]\xc9\x04z5L\x8aD\xa2\x94\xca7rM(\x93H\xfb\x9d\xba\xad>\xd0\x9e-I\xfaX\x9e\xa7k\nd\xf4%0J\xaf\x00,+\x92l\x9a\'p\x8a\xe6\xc1-\xa0\n\xea\xba\xaf\xe0\n\xc2\xb0\xa6\x90t,\xc2\xae\xeb\xcb\x10>\xb1lk\x1f\x13\xb2L\x93(\xcc3\x91k:\xce3L\xe3>\xd3\x11\xad;R\xd5\xb5\xae\x1cu\x1d\xc7\x91\xec}\x1f\xc8\x12\x0c\x80\xe2\xa0H\x13\x8e\xe5\xa1\x08b \xe8:H\xa2,\xa6:\xeak\xb2\xa1\xa4\x8a\x12P\xa8\xa7\xebJ\xb3\x02\xc3R\xeav\x97%\x89BF\xa2(\xc8\xe2\x98\x8c"O\x92\x90\xa3(\x8a\xa4\xc7)J\x89\x1b\xbd\x04\xa7\xea\x8aP\x96<I\xd2\xd6\xb4\xa5O\xba|\xad\xcb\xa9\xa2h\xf3\xadp"\xe6\xb9\'0\xdac=<t\\8\x00\xc3\xcb\xaa\xee\xbe1C\xf8\x02@R\xe0\t\x05MS\x8c\x83-\x18\xc5\xed\x14d\x00\xb4\x91\xa0\x03\x1a\xb5\x04|o!U\x95m]W\xd6\x15\x8c\x7f#9\x08#\x96\xe6\xc9N{\xa2\xa5#\x0e\xb2\x8e\xecN\x0f\xe4\xad\x04\xc0t\x04$\xb3@\x13\nH\xa2#\x88\xc2,\xf8\xd7h\x92\x98\x8f;R\xa4\xc9`\x80.\xe2F\x94[\x89*\xac\xb5\'\xaa\xe2\xd4\xf5*\xa9R\\\x99,)\xda`\xac\xa7\xb3\xc2\xb5u\xd0\xb0\x02\\\x97+)\x85\xd0\xb60,*\xf8=\x807\xe3\x15\x7f\x801#\x19KSl\xb4X\xd03\xf1tgS\xc6\xd5V\x1d\x1cVX\x8e%\x89\xe2\x98\xacv\x82c\x0eS\x98\x84\xb9\xc8\x83\xa4\x89"\xd2z\x90\x8dd\x8aE\xa8\x90\xa4j\x14\xb1\x00^\xb4\x02z\xb4\xad6T\xdff\xa9N\x96l\xe9\xa3\x08\xe2\x8c\x8fX\x08\xe24\x8f(\x8a&R\xaa\xceJ\x04\x16\xb4\xa7\xf3\x15\xb3o%I\xed\xe1\x97\xadIRU\x01@+RX\xb4\xa7\xaa\xf4\xf5{\xa74\x93\x0c\xbd/+\xe6\xc4\xbe\xdf\x8ce6\xca3M#Q\x1a\xb4\xcd%K\x86U\x00\rT\xd55X\xb6\xed\xbb\xef\x1b\xcdd\xe3\xa0\xd2F8\x86!\xce\x83\xa1\')H\xb5\x9c\x8b\xf1\x0e\xaa\x9b\xa1?\xb7\x05\x00\xac\xe6\x1a\xb4\xfe\x94=\x8aD\xd1]I\x8e\x9a)^\xa9\x08\xe4\xcd5\xca\x8e\xe7D\x92[V\xf3\xbf\x05*\xbcd\xae\xff\xdd\xb3\xfe\xa5o\xdb\xaf\xf6\xa7?\xbc3\xd2\xc2\x9c\xd1\x14<>\xc ...

# %%
# response = requests.get(f"https://portal.opentopography.org/API/globaldem?demtype=NASADEM&south=45.196&north=49&west=-122.66&east=-119.95&outputFormat=GTiff&API_Key={config['OPENTOPOGRAPHY_KEY']}")

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
# response.text

# %%
with open(f"data/test_1.tif", 'wb') as f:
    f.write(response.content)

# %%
## Viz data
import rasterio
from rasterio.plot import show as show_rasterio

# %%
image = rasterio.open(f"data/test_1.tif", driver="GTiff", )

# %%
response.headers
# Out:
# {'Date': 'Fri, 23 May 2025 10:50:03 GMT', 'Server': 'Apache', 'Content-Disposition': 'attachment; filename=appRasterSelectAPIService1747997404060-2066364451.tif', 'Access-Control-Allow-Origin': '*', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked', 'Content-Type': 'application/octet-stream'}

# %%
show_rasterio(image)
# Out:
# <Axes: >

# %%
image.height
# Out:
# 155

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image.read(1))
